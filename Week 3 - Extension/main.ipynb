# %% [markdown]
# # Week 3 - Extension

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, root_mean_squared_error

# %%
df = pd.read_csv('student_scores.csv')
df.head()
# Out:
#    id first_name last_name                                  email  gender  \
# 0   1       Paul     Casey         paul.casey.1@gslingacademy.com    male
# 1   2   Danielle  Sandoval  danielle.sandoval.2@gslingacademy.com  female
# 2   3       Tina   Andrews       tina.andrews.3@gslingacademy.com  female
# 3   4       Tara     Clark         tara.clark.4@gslingacademy.com  female
# 4   5    Anthony    Campos     anthony.campos.5@gslingacademy.com    male
#
#    part_time_job  absence_days  extracurricular_activities  \
# 0          False             3                       False
# 1          False             2                       False
# 2          False             9                        True
# 3          False             5                       False
# 4          False             5                       False
#
#    weekly_self_study_hours   career_aspiration  math_score  history_score  \
# 0                       27              Lawyer          73             81
# 1                       47              Doctor          90             86
# 2                       13  Government Officer          81             97
# 3                        3              Artist          71             74
# 4                       10             Unknown          84             77
#
#    physics_score  chemistry_score  biology_score  english_score  \
# 0             93               97             63             80
# 1             96              100             90             88
# 2             95               96             65             77
# 3             88               80             89             63
# 4             65               65             80             74
#
#    geography_score
# 0               87
# 1               90
# 2               94
# 3               86
# 4               76

# %%
print(df.isnull().sum())
# Out:
# id                            0
# first_name                    0
# last_name                     0
# email                         0
# gender                        0
# part_time_job                 0
# absence_days                  0
# extracurricular_activities    0
# weekly_self_study_hours       0
# career_aspiration             0
# math_score                    0
# history_score                 0
# physics_score                 0
# chemistry_score               0
# biology_score                 0
# english_score                 0
# geography_score               0
# dtype: int64

# %%
df = df.drop(columns=['id'], errors='ignore')
df.head()
# Out:
#   first_name last_name                                  email  gender  \
# 0       Paul     Casey         paul.casey.1@gslingacademy.com    male
# 1   Danielle  Sandoval  danielle.sandoval.2@gslingacademy.com  female
# 2       Tina   Andrews       tina.andrews.3@gslingacademy.com  female
# 3       Tara     Clark         tara.clark.4@gslingacademy.com  female
# 4    Anthony    Campos     anthony.campos.5@gslingacademy.com    male
#
#    part_time_job  absence_days  extracurricular_activities  \
# 0          False             3                       False
# 1          False             2                       False
# 2          False             9                        True
# 3          False             5                       False
# 4          False             5                       False
#
#    weekly_self_study_hours   career_aspiration  math_score  history_score  \
# 0                       27              Lawyer          73             81
# 1                       47              Doctor          90             86
# 2                       13  Government Officer          81             97
# 3                        3              Artist          71             74
# 4                       10             Unknown          84             77
#
#    physics_score  chemistry_score  biology_score  english_score  \
# 0             93               97             63             80
# 1             96              100             90             88
# 2             95               96             65             77
# 3             88               80             89             63
# 4             65               65             80             74
#
#    geography_score
# 0               87
# 1               90
# 2               94
# 3               86
# 4               76

# %%
plt.scatter(df['LotArea'], df['SalePrice'], c=df['SalePrice'], cmap='viridis')
plt.xlabel('Lot Area')
plt.ylabel('Sale Price')
plt.colorbar(label='Sale Price')
plt.title('Lot Area vs Sale Price')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'LotArea'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 plt.scatter(df['LotArea'], df['SalePrice'], c=df['SalePrice'], cmap='viridis')
#       2 plt.xlabel('Lot Area')
#       3 plt.ylabel('Sale Price')
#
# File /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'LotArea'

# %%
X = df['Street'].value_counts()['Pave']
Y = len(df)
print(X/Y*100)

# Justification to remove the 'Street' column:
# The 'Street' column has very little variance, with the vast majority of entries being 'Pave'.
df = df.drop(columns=['Street'], errors='ignore')
df.head()
# Out:
# 99.58904109589041
#    LotArea Neighborhood  YearBuilt  ...  PavedDrive PoolArea  SalePrice
# 0     8450      CollgCr       2003  ...           Y        0     208500
# 1     9600      Veenker       1976  ...           Y        0     181500
# 2    11250      CollgCr       2001  ...           Y        0     223500
# 3     9550      Crawfor       1915  ...           Y        0     140000
# 4    14260      NoRidge       2000  ...           Y        0     250000
#
# [5 rows x 12 columns]

# %%
df = pd.get_dummies(df)
df.head()
# Out:
#    LotArea  YearBuilt  YearRemodAdd  ...  PavedDrive_N  PavedDrive_P  PavedDrive_Y
# 0     8450       2003          2003  ...         False         False          True
# 1     9600       1976          1976  ...         False         False          True
# 2    11250       2001          2002  ...         False         False          True
# 3     9550       1915          1970  ...         False         False          True
# 4    14260       2000          2000  ...         False         False          True
#
# [5 rows x 45 columns]

# %%
X = df.drop("SalePrice", axis=1)
Y = df["SalePrice"]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
# R-squared is a statistical measure that represents the proportion of the variance for a dependent variable that's explained by an 
# independent variable or variables in a regression model.

Y_pred = model.predict(X_test)

# The R-squared value indicates how well the model explains the variability of the response data around its mean.
r2 = r2_score(Y_test, Y_pred)
print(f'R-squared: {r2}')

# The RMSE value provides a measure of how accurately the model predicts the response, with lower values indicating better fit.
rmse = root_mean_squared_error(Y_test, Y_pred)
print(f'Root Mean Squared Error: {rmse}')
# Out:
# R-squared: 0.716450022978177
# Root Mean Squared Error: 44481.887612493105
